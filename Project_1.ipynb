# %% [markdown]
# #Fundamental Booster

# %%
print("====================================")
print(" Welcome to Personal Data Collector ")
print("====================================")

# Taking input from user

name = input("Enter your name: ")
age = int(input("Enter your age: "))
height = float(input("Enter your height (in meters): "))
fav_num = int(input("Enter your favourite number: "))

birth_year = 2026 - age

height_int = int(height)


print("\n========== User Information ==========")

print("Name:", name, "| Type:", type(name), "| Memory Address:", id(name))
print("Age:", age, "| Type:", type(age), "| Memory Address:", id(age))
print("Height:", height, "| Type:", type(height), "| Memory Address:", id(height))
print("Favourite Number:", fav_num, "| Type:", type(fav_num), "| Memory Address:", id(fav_num))

print("\n========== Data Processing ==========")

print("Approximate Birth Year:", birth_year)

print("\n========== Type Casting ==========")

print("Original Height:", height)
print("Height after int() conversion:", height_int)


print("\nThank you for using the Personal Data Collector!")
print("Keep learning Python. Goodbye!")
# Out:
# ====================================
#  Welcome to Personal Data Collector
# ====================================
# Enter your name: Ashish Gupta
# Enter your age: 20
# Enter your height (in meters): 179
# Enter your favourite number: 7
#
# ========== User Information ==========
# Name: Ashish Gupta | Type: <class 'str'> | Memory Address: 133772402806192
# Age: 20 | Type: <class 'int'> | Memory Address: 11645960
# Height: 179.0 | Type: <class 'float'> | Memory Address: 133772402754992
# Favourite Number: 7 | Type: <class 'int'> | Memory Address: 11645544
#
# ========== Data Processing ==========
# Approximate Birth Year: 2006
#
# ========== Type Casting ==========
# Original Height: 179.0
# Height after int() conversion: 179
#
# Thank you for using the Personal Data Collector!
# Keep learning Python. Goodbye!
